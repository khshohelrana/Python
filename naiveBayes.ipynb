# %% [markdown]
# <a href="https://colab.research.google.com/github/khshohelrana/Python/blob/main/naiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import essential library
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#load the  dataset
path = "/content/news.csv"
df = pd.read_csv(path)
df
# Out:
#                                                  text      lebel
# 0    LeBron James Leads Lakers to Victory with 40-...    Sports
# 1    Manchester City Clinches Premier League Title...    Sports
# 2   Serena Williams Advances to Wimbledon Final Af...    Sports
# 3   Lewis Hamilton Wins Formula 1 Grand Prix in Mo...    Sports
# 4    Golden State Warriors Secure Playoff Spot wit...    Sports
# ..                                                ...        ...
# 95  Israeli Parliament Passes Bill to Expand Settl...  politics
# 96  Afghan President Holds Talks with Taliban Lead...  politics
# 97  Brazilian Parliament Votes on Proposed Pension...  politics
# 98   Ukrainian Government Implements Anti-Corrupti...  politics
# 99   Pakistani Parliament Debates Military Spendin...  politics
#
# [100 rows x 2 columns]

# %%
# Separate features (text) and target variable (lebel)
X = df["text"]
y = df["lebel"]



#Convert text data to numerical features using TF-IDF
vectorizer = TfidfVectorizer(max_features=2000)


X_features = vectorizer.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.2, random_state=42)

# Train the Naive Bayes classifier
clf = MultinomialNB()
clf.fit(X_train, y_train)

# Make predictions on testing set
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))

# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
#               precision    recall  f1-score   support
#
#      Sports        1.00      0.92      0.96        12
#    politics        0.89      1.00      0.94         8
#
#     accuracy                           0.95        20
#    macro avg       0.94      0.96      0.95        20
# weighted avg       0.96      0.95      0.95        20
#
# Accuracy: 0.95

# %%
#not complete these one
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

path = ""
df = pd.read_csv(path)

# Separate features (content) and target variable (title)
X = df["text"]
y = df["lebel"]



#Convert text data to numerical features using TF-IDF
vectorizer = TfidfVectorizer(max_features=2000)


X_features = vectorizer.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.2, random_state=42)

# Train the Naive Bayes classifier
clf = MultinomialNB()
clf.fit(X_train, y_train)

# Make predictions on testing set
y_pred = clf.predict(X_test)

# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
